# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
url = "https://dps.psx.com.pk/indices"
r =  requests.get(url)
soup = BeautifulSoup(r.text,"lxml")

table  = soup.find("table",class_="tbl")

headers = table.find('thead',class_="tbl__head")

titles = []

for i in headers:
    title = i.text
    titles.append(title)
 
df = pd.DataFrame(columns=titles)
df.head()

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

url = "https://dps.psx.com.pk/indices"
r = requests.get(url)
soup = BeautifulSoup(r.text, "lxml")

table = soup.find("table", class_="tbl")
headers = table.find('thead', class_="tbl__head")

titles = []

if headers:
    header_cells = headers.find_all('th')
    for header in header_cells:
        title = header.text.strip()
        titles.append(title)

df = pd.DataFrame(columns=titles)
print(df.head())

# %%
# Step 1: Import the necessary libraries
import pandas as pd
import requests
from bs4 import BeautifulSoup

#Step 2: Define the URL and make a request to fetch the web page

url = "https://dps.psx.com.pk/indices"
r = requests.get(url)

#Step 3: Create a BeautifulSoup object to parse the HTML content of the web page
soup = BeautifulSoup(r.text, "lxml")

#Step 4: Find the table element with class "tbl" that contains the data
table = soup.find("table", class_="tbl")

#Step 5: Find the table header (thead) to extract the column names
headers = table.find('thead', class_="tbl__head")

#Step 6: Get the header titles by finding all the `th` elements in the header

titles = []
if headers:
    header_cells = headers.find_all('th')
    for header in header_cells:
        title = header.text.strip()
        titles.append(title)

#Step 7: Create an empty DataFrame with the extracted header titles
df = pd.DataFrame(columns=titles)

#Step 8: Find the table body (tbody) containing the data rows
body = table.find('tbody')

#Step 9: Find all rows (tr) in the table body
rows = body.find_all('tr')

#Step 10: Loop through the rows and extract data from the cells (td)
for row in rows:
    data_cells = row.find_all('td')
    data = [cell.text.strip() for cell in data_cells]
    
#Step 11: Create a dictionary with column names as keys and row data as values
    row_data = dict(zip(titles, data))
    
#Step 12: Append the row data to the DataFrame
    df = df.append(row_data, ignore_index=True)
#Step 13: Display the populated DataFrame

# %%
df.head(25)

# %% [markdown]
# ## **Selenium**

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

url = "https://dps.psx.com.pk/listings"

# Use Chrome WebDriver (make sure chromedriver executable is in the same directory)
driver = webdriver.Chrome()

driver.get(url)

# Wait for the dynamic content to load (you may need to adjust the wait time based on the website's loading speed)
driver.implicitly_wait(10)

# Get the page source after JavaScript has rendered the table
html = driver.page_source

# Close the WebDriver
driver.quit()

# Now use BeautifulSoup to parse the page source
soup = BeautifulSoup(html, "lxml")

table = soup.find('table', class_="tbl dataTable no-footer")
#DataTables_Table_0
# Step 5: Find the table header (thead) to extract the column names
headers = table.find('thead', class_="tbl__head")

# Step 6: Get the header titles by finding all the `th` elements in the header
titles = []
if headers:
    header_cells = headers.find_all('th')
    for header in header_cells:
        title = header.text.strip()
        titles.append(title)

#Step 7: Create an empty DataFrame with the extracted header titles
df = pd.DataFrame(columns=titles)

#Step 8: Find the table body (tbody) containing the data rows
body = table.find('tbody')

#Step 9: Find all rows (tr) in the table body
rows = body.find_all('tr')

#Step 10: Loop through the rows and extract data from the cells (td)
for row in rows:
    data_cells = row.find_all('td')
    data = [cell.text.strip() for cell in data_cells]
    
#Step 11: Create a dictionary with column names as keys and row data as values
    row_data = dict(zip(titles, data))
    
#Step 12: Append the row data to the DataFrame
    df = df.append(row_data, ignore_index=True)
#Step 13: Display the populated DataFrame
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\1825769185.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\1825769185.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\1825769185.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\1825769185.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\1825769185.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\1825769185.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\1825769185.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\1825769185.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\1825769185.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\1825769185.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\1825769185.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\1825769185.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\1825769185.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\1825769185.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\1825769185.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\1825769185.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\1825769185.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\1825769185.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\1825769185.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\1825769185.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\1825769185.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\1825769185.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\1825769185.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\1825769185.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\1825769185.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)

# %%
df.head(25)
# Out:
#      Symbol                             Name  \
# 0       786              786 Investments Ltd
# 1      AABS      AL-Abbas Sugar Mills Ltd.XD
# 2       ABL                 Allied Bank Ltd.
# 3      ABOT       Abbott Lab (Pakistan) Ltd.
# 4    ACIETF       Alfalah Consumer Index ETF
# 5      ACPL      Attock Cement Pakistan Ltd.
# 6     ADAMS            Adam Sugar Mills Ltd.
# 7      ADMM        Artistic Denim Mills Ltd.
# 8       AEL                AEL Textiles Ltd.
# 9      AGHA              Agha Steel Ind.Ltd.
# 10     AGIC     Askari General Insurance Co.
# 11     AGIL         Agriauto Industries Ltd.
# 12      AGL                 Agritech Limited
# 13  AGLNCPS       Agritech Non-Voting (Pref)
# 14      AGP                     AGP Limited.
# 15    AGSML        Abdullah Shah Ghazi Sugar
# 16     AGTL           Al-Ghazi Tractors Ltd.
# 17     AHCL      Arif Habib Corporation Ltd.
# 18      AHL              Arif Habib Limited.
# 19     AHTM  Ahmad Hassan Textile Mills Ltd.
# 20     AICL       Adamjee Insurance Co. Ltd.
# 21  AIRLINK          Air Link Communication.
# 22     AKBL                 Askari Bank Ltd.
# 23    AKDHL          AKD Hospitality Limited
# 24    AKDSL          AKD Securities Limited.
#
#                                       Sector Clearing Type         Shares  \
# 0   INV. BANKS / INV. COS. / SECURITIES COS.            NC     14,973,750
# 1                  SUGAR & ALLIED INDUSTRIES            NC     17,362,300
# 2                           COMMERCIAL BANKS            NC  1,145,073,830
# 3                            PHARMACEUTICALS            NC     97,900,302
# 4                      EXCHANGE TRADED FUNDS            NC      6,150,000
# 5                                     CEMENT            NC    137,426,961
# 6                  SUGAR & ALLIED INDUSTRIES            NC     17,291,008
# 7                          TEXTILE COMPOSITE            NC     84,000,000
# 8                          TEXTILE COMPOSITE            NC      8,000,000
# 9                                ENGINEERING            NC    604,879,058
# 10                                 INSURANCE            NC     71,901,898
# 11            AUTOMOBILE PARTS & ACCESSORIES            NC     36,000,000
# 12                                  CHEMICAL            NC    392,430,000
# 13                                  CHEMICAL            NC    159,334,269
# 14                           PHARMACEUTICALS            NC    280,000,000
# 15                 SUGAR & ALLIED INDUSTRIES            NC     79,261,700
# 16                      AUTOMOBILE ASSEMBLER            NC     57,964,201
# 17                                FERTILIZER            NC    408,375,000
# 18  INV. BANKS / INV. COS. / SECURITIES COS.            NC     65,340,000
# 19                         TEXTILE COMPOSITE            NC      8,471,535
# 20                                 INSURANCE            NC    350,000,000
# 21                TECHNOLOGY & COMMUNICATION            NC    395,269,231
# 22                          COMMERCIAL BANKS            NC  1,449,299,207
# 23                             MISCELLANEOUS            NC      2,507,273
# 24  INV. BANKS / INV. COS. / SECURITIES COS.            NC    557,834,171
#
#      Free Float              Listed In
# 0     5,240,813                 ALLSHR
# 1     1,736,230                 ALLSHR
# 2   114,507,383           ALLSHRKSE100
# 3    21,090,584  ALLSHRKMIALLSHRKSE100
# 4     6,390,000
# 5    27,485,392        ALLSHRKMIALLSHR
# 6     4,322,741        ALLSHRKMIALLSHR
# 7     4,200,000                 ALLSHR
# 8     2,400,000                 ALLSHR
# 9   241,951,623     ACIALLSHRKMIALLSHR
# 10   28,760,758                 ALLSHR
# 11   21,600,000        ALLSHRKMIALLSHR
# 12  215,836,500                 ALLSHR
# 13   71,700,421                 ALLSHR
# 14   84,000,000  ALLSHRKMIALLSHRKSE100
# 15   19,815,417                 ALLSHR
# 16    3,637,450        ALLSHRKMIALLSHR
# 17   40,837,500                 ALLSHR
# 18   19,602,000                 ALLSHR
# 19    1,270,730        ALLSHRKMIALLSHR
# 20  227,500,000           ALLSHRKSE100
# 21   98,817,308  ALLSHRKMIALLSHRKSE100
# 22  434,789,762           ALLSHRKSE100
# 23    1,002,909                 ALLSHR
# 24   27,891,709                 ALLSHR

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

url = "https://dps.psx.com.pk/listings"

# Use Chrome WebDriver (make sure chromedriver executable is in the same directory)
driver = webdriver.Chrome()

driver.get(url)

# Wait for the dynamic content to load (you may need to adjust the wait time based on the website's loading speed)
driver.implicitly_wait(10)

# Get the page source after JavaScript has rendered the table
html = driver.page_source

# Close the WebDriver
driver.quit()

# Now use BeautifulSoup to parse the page source
soup = BeautifulSoup(html, "lxml")

table = soup.find('table', class_="tbl dataTable no-footer")
#DataTables_Table_0
# Step 5: Find the table header (thead) to extract the column names
headers = table.find('thead', class_="tbl__head")

# Step 6: Get the header titles by finding all the `th` elements in the header
titles = []
if headers:
    header_cells = headers.find_all('th')
    for header in header_cells:
        title = header.text.strip()
        titles.append(title)

#Step 7: Create an empty DataFrame with the extracted header titles
df = pd.DataFrame(columns=titles)

#Step 8: Find the table body (tbody) containing the data rows
body = table.find('tbody')



#Step 9: Find all rows (tr) in the table body
rows = body.find_all('tr')

#Step 10: Loop through the rows and extract data from the cells (td)
for row in rows:
    data_cells = row.find_all('td')
    data = [cell.text.strip() for cell in data_cells]
    
#Step 11: Create a dictionary with column names as keys and row data as values
    row_data = dict(zip(titles, data))
    
#Step 12: Append the row data to the DataFrame
    df = df.append(row_data, ignore_index=True)
#Step 13: Display the populated DataFrame
df.shape()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\463854588.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\463854588.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\463854588.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\463854588.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\463854588.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\463854588.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\463854588.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\463854588.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\463854588.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\463854588.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\463854588.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\463854588.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\463854588.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\463854588.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\463854588.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\463854588.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\463854588.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\463854588.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\463854588.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\463854588.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\463854588.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\463854588.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\463854588.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\463854588.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_4680\463854588.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

url = "https://dps.psx.com.pk/listings"

# Use Chrome WebDriver (make sure chromedriver executable is in the same directory)
driver = webdriver.Chrome()

driver.get(url)

# Wait for the dynamic content to load (you may need to adjust the wait time based on the website's loading speed)
driver.implicitly_wait(10)

# Get the page source after JavaScript has rendered the table
html = driver.page_source

# Close the WebDriver
driver.quit()

# Now use BeautifulSoup to parse the page source
soup = BeautifulSoup(html, "lxml")

table = soup.find('table', class_="tbl dataTable no-footer")
#DataTables_Table_0
# Step 5: Find the table header (thead) to extract the column names
headers = table.find('thead', class_="tbl__head")

# Step 6: Get the header titles by finding all the `th` elements in the header
titles = []
if headers:
    header_cells = headers.find_all('th')
    for header in header_cells:
        title = header.text.strip()
        titles.append(title)

#Step 7: Create an empty DataFrame with the extracted header titles
df = pd.DataFrame(columns=titles)

#Step 8: Find the table body (tbody) containing the data rows
body = table.find('tbody')


#Step 9: Find all rows (tr) in the table body
rows = body.find_all('tr')

#Step 10: Loop through the rows and extract data from the cells (td)
for row in rows:
    data_cells = row.find_all('td')
    data = [cell.text.strip() for cell in data_cells]
    
#Step 11: Create a dictionary with column names as keys and row data as values
    row_data = dict(zip(titles, data))
    
#Step 12: Append the row data to the DataFrame
    df = df.append(row_data, ignore_index=True)
#Step 13: Display the populated DataFrame
df.shape
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6384\1578117854.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6384\1578117854.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6384\1578117854.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6384\1578117854.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6384\1578117854.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6384\1578117854.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6384\1578117854.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6384\1578117854.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6384\1578117854.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6384\1578117854.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6384\1578117854.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6384\1578117854.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6384\1578117854.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6384\1578117854.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6384\1578117854.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6384\1578117854.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6384\1578117854.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6384\1578117854.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6384\1578117854.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6384\1578117854.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6384\1578117854.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6384\1578117854.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6384\1578117854.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6384\1578117854.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6384\1578117854.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row_data, ignore_index=True)
# (25, 7)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

def scrape_page_data(url):
    # Use Chrome WebDriver (make sure chromedriver executable is in the same directory)
    driver = webdriver.Chrome()
    driver.get(url)

    # Wait for the dynamic content to load (you may need to adjust the wait time based on the website's loading speed)
    driver.implicitly_wait(10)

    # Get the page source after JavaScript has rendered the table
    html = driver.page_source

    # Close the WebDriver
    driver.quit()

    # Now use BeautifulSoup to parse the page source
    soup = BeautifulSoup(html, "lxml")

    table = soup.find('table', class_="tbl dataTable no-footer")

    # Step 5: Find the table header (thead) to extract the column names
    headers = table.find('thead', class_="tbl__head")

    # Step 6: Get the header titles by finding all the `th` elements in the header
    titles = []
    if headers:
        header_cells = headers.find_all('th')
        for header in header_cells:
            title = header.text.strip()
            titles.append(title)

    # Step 7: Create an empty DataFrame with the extracted header titles
    df = pd.DataFrame(columns=titles)

    # Step 8: Find the table body (tbody) containing the data rows
    body = table.find('tbody')

    # Step 9: Find all rows (tr) in the table body
    rows = body.find_all('tr')

    # Step 10: Loop through the rows and extract data from the cells (td)
    for row in rows:
        data_cells = row.find_all('td')
        data = [cell.text.strip() for cell in data_cells]

        # Step 11: Create a dictionary with column names as keys and row data as values
        row_data = dict(zip(titles, data))

        # Step 12: Append the row data to the DataFrame
        df = df.append(row_data, ignore_index=True)

    return df

def scrape_all_pages(base_url):
    # Get data from the first page
    df = scrape_page_data(base_url)

    # Find the total number of pages
    last_page = 1  # Set to 1 initially, as the first page is already scraped
    pagination = soup.find('ul', class_='pagination')
    if pagination:
        pages = pagination.find_all('li')
        for page in pages:
            try:
                page_number = int(page.text)
                last_page = max(last_page, page_number)
            except ValueError:
                pass

    # Scrape data from rest of the pages
    for page_num in range(2, last_page + 1):
        page_url = f"{base_url}?page={page_num}"
        df_page = scrape_page_data(page_url)
        df = df.append(df_page, ignore_index=True)

    return df

if __name__ == "__main__":
    base_url = "https://dps.psx.com.pk/listings"
    result_df = scrape_all_pages(base_url)
    print(result_df.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# e:\GitHub\100_days_ML\day18(webscrap)\dps.ipynb Cell 13 in 8
#      <a href='vscode-notebook-cell:/e%3A/GitHub/100_days_ML/day18%28webscrap%29/dps.ipynb#X21sZmlsZQ%3D%3D?line=80'>81</a> if __name__ == "__main__":
#      <a href='vscode-notebook-cell:/e%3A/GitHub/100_days_ML/day18%28webscrap%29/dps.ipynb#X21sZmlsZQ%3D%3D?line=81'>82</a>     base_url = "https://dps.psx.com.pk/listings"
# ---> <a href='vscode-notebook-cell:/e%3A/GitHub/100_days_ML/day18%28webscrap%29/dps.ipynb#X21sZmlsZQ%3D%3D?line=82'>83</a>     result_df = scrape_all_pages(base_url)
#      <a href='vscode-notebook-cell:/e%3A/GitHub/100_days_ML/day18%28webscrap%29/dps.ipynb#X21sZmlsZQ%3D%3D?line=83'>84</a>     print(result_df.shape)
#
# e:\GitHub\100_days_ML\day18(webscrap)\dps.ipynb Cell 13 in 5
#      <a href='vscode-notebook-cell:/e%3A/GitHub/100_days_ML/day18%28webscrap%29/dps.ipynb#X21sZmlsZQ%3D%3D?line=56'>57</a> def scrape_all_pages(base_url):
#      <a href='vscode-notebook-cell:/e%3A/GitHub/100_days_ML/day18%28webscrap%29/dps.ipynb#X21sZmlsZQ%3D%3D?line=57'>58</a>     # Get data from the first page
# ---> <a href='vscode-notebook-cell:/e%3A/GitHub/100_days_ML/day18%28webscrap%29/dps.ipynb#X21sZmlsZQ%3D%3D?line=58'>59</a>     df = scrape_page_data(base_url)
#      <a href='vscode-notebook-cell:/e%3A/GitHub/100_days_ML/day18%28webscrap%29/dps.ipynb#X21sZmlsZQ%3D%3D?line=60'>61</a>     # Find the total number of pages
#      <a href='vscode-notebook-cell:/e%3A/GitHub/100_days_ML/day18%28webscrap%29/dps.ipynb#X21sZmlsZQ%3D%3D?line=61'>62</a>     last_page = 1  # Set to 1 initially, as the first page is already scraped
#
# e:\GitHub\100_days_ML\day18(webscrap)\dps.ipynb Cell 13 in 2
#      <a href='vscode-notebook-cell:/e%3A/GitHub/100_days_ML/day18%28webscrap%29/dps.ipynb#X21sZmlsZQ%3D%3D?line=21'>22</a> table = soup.find('table', class_="tbl dataTable no-footer")
#      <a href='vscode-notebook-cell:/e%3A/GitHub/100_days_ML/day18%28webscrap%29/dps.ipynb#X21sZmlsZQ%3D%3D?line=23'>24</a> # Step 5: Find the table header (thead) to extract the column names
# ---> <a href='vscode-notebook-cell:/e%3A/GitHub/100_days_ML/day18%28webscrap%29/dps.ipynb#X21sZmlsZQ%3D%3D?line=24'>25</a> headers = table.find('thead', class_="tbl__head")
#      <a href='vscode-notebook-cell:/e%3A/GitHub/100_days_ML/day18%28webscrap%29/dps.ipynb#X21sZmlsZQ%3D%3D?line=26'>27</a> # Step 6: Get the header titles by finding all the `th` elements in the header
#      <a href='vscode-notebook-cell:/e%3A/GitHub/100_days_ML/day18%28webscrap%29/dps.ipynb#X21sZmlsZQ%3D%3D?line=27'>28</a> titles = []
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\GitHub\100_days_ML\day18(webscrap)\dps.ipynb Cell 14 in 1
# ----> <a href='vscode-notebook-cell:/e%3A/GitHub/100_days_ML/day18%28webscrap%29/dps.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> df.shape
#
# NameError: name 'df' is not defined
